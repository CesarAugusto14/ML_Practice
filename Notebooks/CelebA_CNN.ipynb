# %% [markdown]
# # CelebA CNN for Smile Classification

# %%
import hub
import torch
import torch.nn as nn
import torchvision
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from torchvision import transforms, datasets
from torch.utils.data import random_split, DataLoader
from torchsummary import summary
from tqdm import tqdm

# %% [markdown]
# ## Loading The Dataset:

# %%
ds = hub.load("hub://activeloop/celeb-a-val")
ds_test = hub.load("hub://activeloop/celeb-a-test")
# Out:
# hub://activeloop/celeb-a-val loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/celeb-a-val
# hub://activeloop/celeb-a-test loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/celeb-a-test

# %% [markdown]
# ## Visualizing the Dataset

# %%
plt.figure(figsize=(20,10))
for i in range(10):
    plt.subplot(2,5, i+1)
    plt.imshow(ds.tensors['images'][i].numpy())
    plt.axis('off')
    plt.title(ds.tensors['smiling'].numpy()[:,0][i])

# %%
# THE DATA FROM CELEBA IS NOT AVAILABLE!
